# %%
from pymongo import MongoClient
import pandas as pd

# Requires the PyMongo package.
# https://api.mongodb.com/python/current

client = MongoClient('mongodb://localhost:27017/')
filter={}

result = client['local']['ex14-03-26'].find(
  filter=filter
)

df = pd.DataFrame (list(result))
df
# Out:
#                          _id               Nome  Idade     Salário
# 0   69c31bacb821b052da08462f      Colby Bezerra     39   $3,655.82
# 1   69c31bacb821b052da084630    Raphael Caetano     28   $3,434.08
# 2   69c31bacb821b052da084631     Vivien Moreira     44   $5,758.39
# 3   69c31bacb821b052da084632    Dominic Pacheco     18   $6,746.30
# 4   69c31bacb821b052da084633     Colorado Felix     53   $5,120.70
# 5   69c31bacb821b052da084634        Lucy Borges     38   $8,357.69
# 6   69c31bacb821b052da084635         Levi Alves     41   $9,724.53
# 7   69c31bacb821b052da084636      Joseph Nonato     32   $2,410.71
# 8   69c31bacb821b052da084637      Kenyon Cabral     33   $9,532.24
# 9   69c31bacb821b052da084638       Quinn Vieira     43   $9,148.76
# 10  69c31bacb821b052da084639  Ferris de Andrade     54  $10,287.78
# 11  69c31bacb821b052da08463a    Giselle Ribeiro     48   $7,651.70
# 12  69c31bacb821b052da08463b   Chancellor Viana     38   $7,849.33
# ...
